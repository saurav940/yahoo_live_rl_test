# %%
import pandas as pd

# %%
games = pd.read_csv('Train.csv')

# %%
games.head()
# Out:
#      Open   Close    High     Low    Volume
# 0  280.91  276.23  283.52  274.05  17366588
# 1  279.08  274.63  279.17  268.84  20957180
# 2  278.21  296.51  297.48  275.65  70540056
# 3  300.04  296.27  302.50  294.34  21372131
# 4  296.37  295.30  297.43  291.73  13472484

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1077 entries, 0 to 1076
# Data columns (total 5 columns):
# Open      1077 non-null float64
# Close     1077 non-null float64
# High      1077 non-null float64
# Low       1077 non-null float64
# Volume    1077 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 42.2 KB

# %%
games['High'].mean()
# Out:
# 267.04734447539516

# %%
games['Low'].max()
# Out:
# 357.25

# %%
games[games['High']== games['Low'].max()]
# Out:
# Empty DataFrame
# Columns: [Open, Close, High, Low, Volume]
# Index: []

# %%
games[games['High']== games['Low'].min()]
# Out:
# Empty DataFrame
# Columns: [Open, Close, High, Low, Volume]
# Index: []

# %%
games['Low'].nunique()
# Out:
# 922

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
games.dropna(inplace=True)

# %%
sns.distplot(games['Close'])

# %%
sns.distplot(games['Low'])

# %%
sns.distplot(games['High'])

# %%
sns.jointplot(games['High'], games['Low'])

# %%
sns.pairplot(games[['High', 'Low', 'Close' , 'Volume']])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e3ce77845b44> in <module>
#       1 sns.pairplot(games[['High', 'Low', 'Close' , 'Volume']])
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.stripplot(games['High'], games['Close'], jitter=True)

# %%
# Out:
#   File "<ipython-input-28-9edcda30ca69>", line 1
#     sns.regplot(x="Close", y="Volume", data=games[games['Close'] < 50]
#                                                                       ^
# SyntaxError: unexpected EOF while parsing
